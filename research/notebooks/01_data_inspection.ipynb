# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_parquet(f"../data/lidar_cable_points_easy.parquet", "auto")
data.head()
# Out:
#               x          y          z
# 2211   6.196634 -13.157755  10.582272
# 2905 -10.440643  17.264460  10.926065
# 1411   2.977432  -3.552676  10.072814
# 251    5.924494 -10.974960  10.342501
# 794   -7.062873  12.850664  10.557997

# %%
difficulties = ["easy","medium","hard","extrahard"]
data_files = [f"lidar_cable_points_{dif}.parquet" for dif in difficulties]

fig = plt.figure(figsize=(12,10))


for i, diff in enumerate(difficulties):
    ax = fig.add_subplot(2,2,i+1,projection="3d")
    data = pd.read_parquet(f"../data/lidar_cable_points_{diff}.parquet", "auto")
    ax.scatter(data["x"], data["y"], data["z"])
    ax.set_title(diff.capitalize())
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")

plt.tight_layout()
plt.show()
